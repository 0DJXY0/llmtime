# %%
import os
os.environ['OMP_NUM_THREADS'] = '4'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import openai
openai.api_key = os.environ['OPENAI_API_KEY']
openai.api_base = os.environ.get("OPENAI_API_BASE", "https://api.openai.com/v1")
from data.serialize import SerializerSettings
from models.utils import grid_iter
from models.promptcast import get_promptcast_predictions_data
from models.darts import get_arima_predictions_data
from models.llmtime import get_llmtime_predictions_data
from data.small_context import get_datasets
from models.validation_likelihood_tuning import get_autotuned_predictions_data
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import log_loss
import time

# %load_ext autoreload
# %autoreload 2

def plot_preds(train, test, pred_dict, model_name, show_samples=False):
    pred = pred_dict['median']
    pred = pd.Series(pred, index=test.index)
    error_mse = mean_squared_error(
                y_true = test,
                y_pred = pred
            )
    error_mae = mean_absolute_error(test, pred)
    print(f"Test error (MSE): {error_mse}")
    print(f"Test error (MAE): {error_mae}")
    plt.figure(figsize=(8, 6), dpi=100)
    plt.plot(train)
    plt.plot(test, label='Truth', color='black')
    plt.plot(pred, label=model_name, color='purple')
    # shade 90% confidence interval
    samples = pred_dict['samples']
    lower = np.quantile(samples, 0.05, axis=0)
    upper = np.quantile(samples, 0.95, axis=0)
    plt.fill_between(pred.index, lower, upper, alpha=0.3, color='purple')
    if show_samples:
        samples = pred_dict['samples']
        # convert df to numpy array
        samples = samples.values if isinstance(samples, pd.DataFrame) else samples
        for i in range(min(10, samples.shape[0])):
            plt.plot(pred.index, samples[i], color='purple', alpha=0.3, linewidth=1)
    plt.legend(loc='upper left')
    if 'NLL/D' in pred_dict:
        nll = pred_dict['NLL/D']
        if nll is not None:
            plt.text(0.03, 0.85, f'NLL/D: {nll:.2f}', transform=plt.gca().transAxes, bbox=dict(facecolor='white', alpha=0.5))
    plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gpt4_hypers = dict(
    alpha=0.3,
    basic=True,
    temp=1.0,
    top_p=0.8,
    settings=SerializerSettings(base=10, prec=3, signed=True, time_sep=', ', bit_sep='', minus_sign='-')
)

gpt3_hypers = dict(
    temp=0.7,
    alpha=0.95,
    beta=0.3,
    basic=False,
    settings=SerializerSettings(base=10, prec=3, signed=True, half_bin_correction=True)
)


promptcast_hypers = dict(
    temp=0.7,
    settings=SerializerSettings(base=10, prec=0, signed=True, 
                                time_sep=', ',
                                bit_sep='',
                                plus_sign='',
                                minus_sign='-',
                                half_bin_correction=False,
                                decimal_point='')
)

arima_hypers = dict(p=[12,30], d=[1,2], q=[0])

model_hypers = {
    'LLMTime GPT-3.5': {'model': 'gpt-3.5-turbo-instruct', **gpt3_hypers},
    'LLMTime GPT-4': {'model': 'gpt-4', **gpt4_hypers},
    'LLMTime GPT-3': {'model': 'gpt-3.5-turbo-instruct', **gpt3_hypers},
    'PromptCast GPT-3': {'model': 'gpt-3.5-turbo-instruct', **promptcast_hypers},
    'ARIMA': arima_hypers,
    
}

model_predict_fns = {
    'LLMTime GPT-3': get_llmtime_predictions_data,
    'LLMTime GPT-4': get_llmtime_predictions_data,
    'PromptCast GPT-3': get_promptcast_predictions_data,
    'ARIMA': get_arima_predictions_data,
}

model_names = list(model_predict_fns.keys())

# %%
datasets = get_datasets()
ds_name = 'WineDataset'
data = datasets[ds_name]

train, test = data

# %%
data = pd.read_csv('datasets/Yearly-train.csv')
data = data['V2']
N = 500
data_short = data[1:N]
data_DF = pd.DataFrame(data_short)
data_series = pd.Series(data_short)
print(data_short)
#data = pd.Series(data[0,:])
n = len(data_short)
m = n*3//4
train = data_series[0:m]
test = data_series[m:]# or change to your own data
print(train)
print(test)
# Out:
# 1      2070.000000
# 2      2760.000000
# 3      3380.000000
# 4      1980.000000
# 5      1988.650000
#           ...
# 495     851.412000
# 496    1411.627208
# 497     162.960130
# 498    5479.422000
# 499    3726.863415
# Name: V2, Length: 499, dtype: float64
# 1      2070.000000
# 2      2760.000000
# 3      3380.000000
# 4      1980.000000
# 5      1988.650000
#           ...
# 370     256.260762
# 371     726.170947
# 372    1389.120801
# 373    2069.800781
# 374     704.039795
# Name: V2, Length: 374, dtype: float64
# 375    1508.313751
# 376     592.071533
# 377     650.893115
# 378    5588.863125
# 379     344.074609
#           ...
# 495     851.412000
# 496    1411.627208
# 497     162.960130
# 498    5479.422000
# 499    3726.863415
# Name: V2, Length: 125, dtype: float64

# %%
data = pd.read_csv('datasets/memorization/IstanbulTraffic.csv',names = ['data','value'])
data_short = data['value']
print(data_short)
data_series = pd.Series(data_short)
#data_DF = pd.DataFrame(data_short)
#data_series = pd.Series(data_short)
print(data_series)
#data = pd.Series(data[0,:])
n = len(data_short)
m = n*3//4
train = data_series[0:m]
test = data_series[m:]# or change to your own data
print(train)
print(test)
# Out:
# 0      22
# 1       8
# 2       1
# 3       1
# 4       1
#        ..
# 262    78
# 263    80
# 264    71
# 265    51
# 266    31
# Name: value, Length: 267, dtype: int64
# 0      22
# 1       8
# 2       1
# 3       1
# 4       1
#        ..
# 262    78
# 263    80
# 264    71
# 265    51
# 266    31
# Name: value, Length: 267, dtype: int64
# 0      22
# 1       8
# 2       1
# 3       1
# 4       1
#        ..
# 195    33
# 196    38
# 197    38
# 198    44
# 199    49
# Name: value, Length: 200, dtype: int64
# 200    60
# 201    44
# 202    20
# 203    15
# 204     9
#        ..
# 262    78
# 263    80
# 264    71
# 265    51
# 266    31
# Name: value, Length: 67, dtype: int64

# %%
data = pd.read_csv('datasets/memorization/TurkeyPower.csv',names = ['data','value'])
data_short = data['value']
print(data_short)
data_series = pd.Series(data_short)
#data_DF = pd.DataFrame(data_short)
#data_series = pd.Series(data_short)
print(data_series)
#data = pd.Series(data[0,:])
n = len(data_short)
m = n*3//4
train = data_series[0:m]
test = data_series[m:]# or change to your own data
print(train)
print(test)
# Out:
# 0      33035.10
# 1      33616.67
# 2      41659.21
# 3      42099.44
# 4      41934.61
#          ...
# 360    39400.49
# 361    39825.42
# 362    38543.06
# 363    37088.29
# 364    32235.32
# Name: value, Length: 365, dtype: float64
# 0      33035.10
# 1      33616.67
# 2      41659.21
# 3      42099.44
# 4      41934.61
#          ...
# 360    39400.49
# 361    39825.42
# 362    38543.06
# 363    37088.29
# 364    32235.32
# Name: value, Length: 365, dtype: float64
# 0      33035.10
# 1      33616.67
# 2      41659.21
# 3      42099.44
# 4      41934.61
#          ...
# 268    36869.00
# 269    38061.42
# 270    38752.29
# 271    39384.47
# 272    39842.79
# Name: value, Length: 273, dtype: float64
# 273    35137.45
# 274    31048.31
# 275    37982.67
# 276    38212.23
# 277    37821.98
#          ...
# 360    39400.49
# 361    39825.42
# 362    38543.06
# 363    37088.29
# 364    32235.32
# Name: value, Length: 92, dtype: float64

# %%
#basic = False
out = {}
model = 'ARIMA'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Train length: 999, Val length: 500
# Hyperparameter search:   0%|          | 0/4 [00:00<?, ?it/s]
# Hyper: defaultdict(<class 'dict'>, {'p': 12, 'd': 2, 'q': 0})
# 	 Val NLL: 9.250863
# Hyper: defaultdict(<class 'dict'>, {'p': 12, 'd': 1, 'q': 0})
# 	 Val NLL: 9.169168
# Hyper: defaultdict(<class 'dict'>, {'p': 30, 'd': 1, 'q': 0})
# 	 Val NLL: 9.146861
# Hyper: defaultdict(<class 'dict'>, {'p': 30, 'd': 2, 'q': 0})
# 	 Val NLL: 9.183825
# Sampling with best hyper... defaultdict(<class 'dict'>, {'p': 30, 'd': 1, 'q': 0})
#  with NLL 9.146861
#  time: 15.067675113677979 s
# Test error (MSE): 7429878.764326748

# %%
out = {}
model = 'LLMTime GPT-4'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Sampling with best hyper... defaultdict(<class 'dict'>, {'model': 'gpt-4', 'alpha': 0.3, 'basic': True, 'temp': 1.0, 'top_p': 0.8, 'settings': SerializerSettings(base=10, prec=3, signed=True, fixed_length=False, max_val=10000000.0, time_sep=', ', bit_sep='', plus_sign='', minus_sign='-', half_bin_correction=True, decimal_point='', missing_str=' Nan')})
#  with NLL inf
#   0%|                                                                                                                 | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:54<00:00, 54.07s/it]
# Warning: Prediction too short 171 < 200, padded with last value
# Warning: Prediction too short 186 < 200, padded with last value
#  time: 54.08313274383545 s
# Test error (MSE): 9528674.479446175

# %%
out = {}
model = 'LLMTime GPT-4'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Sampling with best hyper... defaultdict(<class 'dict'>, {'model': 'gpt-4', 'alpha': 0.3, 'basic': True, 'temp': 1.0, 'top_p': 0.8, 'settings': SerializerSettings(base=10, prec=3, signed=True, fixed_length=False, max_val=10000000.0, time_sep=', ', bit_sep='', plus_sign='', minus_sign='-', half_bin_correction=True, decimal_point='', missing_str=' Nan')})
#  with NLL inf
#   0%|                                                                                                                 | 0/1 [00:00<?, ?it/s]
#
#
#
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:31<00:00, 31.36s/it]
# Warning: Prediction too short 118 < 125, padded with last value
#  time: 31.368881464004517 s
# Test error (MSE): 3953821.7738575153

# %%
out = {}
model = 'LLMTime GPT-3'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Sampling with best hyper... defaultdict(<class 'dict'>, {'model': 'gpt-3.5-turbo-instruct', 'temp': 0.7, 'alpha': 0.95, 'beta': 0.3, 'basic': False, 'settings': SerializerSettings(base=10, prec=3, signed=True, fixed_length=False, max_val=10000000.0, time_sep=' ,', bit_sep=' ', plus_sign='', minus_sign=' -', half_bin_correction=True, decimal_point='', missing_str=' Nan')})
#  with NLL inf
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.45s/it]
#  time: 11.458375692367554 s
# Test error (MSE): 1068.8346049808583

# %%
out = {}
model = 'LLMTime GPT-4'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Sampling with best hyper... defaultdict(<class 'dict'>, {'model': 'gpt-4', 'alpha': 0.3, 'basic': True, 'temp': 1.0, 'top_p': 0.8, 'settings': SerializerSettings(base=10, prec=3, signed=True, fixed_length=False, max_val=10000000.0, time_sep=', ', bit_sep='', plus_sign='', minus_sign='-', half_bin_correction=True, decimal_point='', missing_str=' Nan')})
#  with NLL inf
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:22<00:00, 22.34s/it]
# Warning: Prediction too short 49 < 67, padded with last value
#  time: 22.34485697746277 s
# Test error (MSE): 1207.7818422014925

# %%
out = {}
model = 'LLMTime GPT-3'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Sampling with best hyper... defaultdict(<class 'dict'>, {'model': 'gpt-3.5-turbo-instruct', 'temp': 0.7, 'alpha': 0.95, 'beta': 0.3, 'basic': False, 'settings': SerializerSettings(base=10, prec=3, signed=True, fixed_length=False, max_val=10000000.0, time_sep=' ,', bit_sep=' ', plus_sign='', minus_sign=' -', half_bin_correction=True, decimal_point='', missing_str=' Nan')})
#  with NLL inf
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.80s/it]
#  time: 12.807356595993042 s
# Test error (MSE): 17833741.47430244

# %%
out = {}
model = 'LLMTime GPT-4'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Sampling with best hyper... defaultdict(<class 'dict'>, {'model': 'gpt-4', 'alpha': 0.3, 'basic': True, 'temp': 1.0, 'top_p': 0.8, 'settings': SerializerSettings(base=10, prec=3, signed=True, fixed_length=False, max_val=10000000.0, time_sep=', ', bit_sep='', plus_sign='', minus_sign='-', half_bin_correction=True, decimal_point='', missing_str=' Nan')})
#  with NLL inf
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:27<00:00, 27.89s/it]
#  time: 27.89187216758728 s
# Test error (MSE): 9490173.759784503

# %%
#basic = False
out = {}
model = 'ARIMA'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Train length: 181, Val length: 92
# Hyperparameter search:   0%|          | 0/4 [00:00<?, ?it/s]
# Hyper: defaultdict(<class 'dict'>, {'p': 12, 'd': 2, 'q': 0})
# 	 Val NLL: 9.541412
# Hyper: defaultdict(<class 'dict'>, {'p': 12, 'd': 1, 'q': 0})
# 	 Val NLL: 9.463919
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Hyper: defaultdict(<class 'dict'>, {'p': 30, 'd': 1, 'q': 0})
# 	 Val NLL: 9.454890
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Hyper: defaultdict(<class 'dict'>, {'p': 30, 'd': 2, 'q': 0})
# 	 Val NLL: 9.574871
# Sampling with best hyper... defaultdict(<class 'dict'>, {'p': 30, 'd': 1, 'q': 0})
#  with NLL 9.454890
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#  time: 13.179077386856079 s
# Test error (MSE): 6779464.740870611

# %%
out = {}
model = 'LLMTime GPT-3'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Sampling with best hyper... defaultdict(<class 'dict'>, {'model': 'gpt-3.5-turbo-instruct', 'temp': 0.7, 'alpha': 0.95, 'beta': 0.3, 'basic': False, 'settings': SerializerSettings(base=10, prec=3, signed=True, fixed_length=False, max_val=10000000.0, time_sep=' ,', bit_sep=' ', plus_sign='', minus_sign=' -', half_bin_correction=True, decimal_point='', missing_str=' Nan')})
#  with NLL inf
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.31s/it]
#  time: 5.321676969528198 s
# Test error (MSE): 19764017.85596392

# %%
out = {}
model = 'LLMTime GPT-4'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Sampling with best hyper... defaultdict(<class 'dict'>, {'model': 'gpt-4', 'alpha': 0.3, 'basic': True, 'temp': 1.0, 'top_p': 0.8, 'settings': SerializerSettings(base=10, prec=3, signed=True, fixed_length=False, max_val=10000000.0, time_sep=', ', bit_sep='', plus_sign='', minus_sign='-', half_bin_correction=True, decimal_point='', missing_str=' Nan')})
#  with NLL inf
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.25s/it]
# Warning: Prediction too short 16 < 36, padded with last value
#  time: 11.251021385192871 s
# Test error (MSE): 15569599.74499103

# %%
#basic = False
out = {}
model = 'ARIMA'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Train length: 104, Val length: 36
# Hyperparameter search:   0%|          | 0/4 [00:00<?, ?it/s]
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Hyper: defaultdict(<class 'dict'>, {'p': 12, 'd': 2, 'q': 0})
# 	 Val NLL: 10.111478
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Hyper: defaultdict(<class 'dict'>, {'p': 12, 'd': 1, 'q': 0})
# 	 Val NLL: 9.779121
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Hyper: defaultdict(<class 'dict'>, {'p': 30, 'd': 1, 'q': 0})
# 	 Val NLL: 10.298407
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/yu/miniconda3/envs/llmtime/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Hyper: defaultdict(<class 'dict'>, {'p': 30, 'd': 2, 'q': 0})
# 	 Val NLL: 10.728272
# Sampling with best hyper... defaultdict(<class 'dict'>, {'p': 12, 'd': 1, 'q': 0})
#  with NLL 9.779121
#  time: 7.877035856246948 s
# Test error (MSE): 9534813.173217617

# %%
out = {}
model = 'LLMTime GPT-3'

hypers = list(grid_iter(model_hypers[model]))
num_samples = 10
t0 = time.time()
pred_dict = get_autotuned_predictions_data(train, test, hypers, num_samples, model_predict_fns[model], verbose=True, parallel=False)
t1 = time.time()
print(' time: ' + str(t1 - t0) + ' s')
out[model] = pred_dict
plot_preds(train, test, pred_dict, model, show_samples=True)
# Out:
# Sampling with best hyper... defaultdict(<class 'dict'>, {'model': 'gpt-3.5-turbo-instruct', 'temp': 0.7, 'alpha': 0.95, 'beta': 0.3, 'basic': False, 'settings': SerializerSettings(base=10, prec=3, signed=True, fixed_length=False, max_val=10000000.0, time_sep=' ,', bit_sep=' ', plus_sign='', minus_sign=' -', half_bin_correction=True, decimal_point='', missing_str=' Nan')})
#  with NLL inf
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.14s/it]
#  time: 4.151080369949341 s
# Test error (MSE): 36812690.98725131
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 11
#       9 print(' time: ' + str(t1 - t0) + ' s')
#      10 out[model] = pred_dict
# ---> 11 plot_preds(train, test, pred_dict, model, show_samples=True)
#
# Cell In[54], line 32, in plot_preds(train, test, pred_dict, model_name, show_samples)
#      26 error_mse = mean_squared_error(
#      27             y_true = test,
#      28             y_pred = pred
#      29         )
#      31 print(f"Test error (MSE): {error_mse}")
# ---> 32 logloss = log_loss(y_true = test, y_pred = pred)
#      33 print(f"Log likelihood (LL): {logloss}")
#      34 plt.figure(figsize=(8, 6), dpi=100)
#
# File ~/miniconda3/envs/llmtime/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/miniconda3/envs/llmtime/lib/python3.9/site-packages/sklearn/metrics/_classification.py:2962, in log_loss(y_true, y_pred, eps, normalize, sample_weight, labels)
#    2960 if len(lb.classes_) != y_pred.shape[1]:
#    2961     if labels is None:
# -> 2962         raise ValueError(
#    2963             "y_true and y_pred contain different number of "
#    2964             "classes {0}, {1}. Please provide the true "
#    2965             "labels explicitly through the labels argument. "
#    2966             "Classes found in "
#    2967             "y_true: {2}".format(
#    2968                 transformed_labels.shape[1], y_pred.shape[1], lb.classes_
#    2969             )
#    2970         )
#    2971     else:
#    2972         raise ValueError(
#    2973             "The number of classes in labels is different "
#    2974             "from that in y_pred. Classes found in "
#    2975             "labels: {0}".format(lb.classes_)
#    2976         )
#
# ValueError: y_true and y_pred contain different number of classes 36, 2. Please provide the true labels explicitly through the labels argument. Classes found in y_true: [13652. 16974. 17466. 19463. 21697. 22724. 22784. 23356. 23565. 23757.
#  23779. 24019. 24179. 24352. 24488. 24735. 25013. 25156. 25236. 25650.
#  26323. 26635. 26805. 26972. 27549. 28496. 29356. 29660. 30207. 30345.
#  30923. 31234. 32857. 37198. 37240. 38687.]
